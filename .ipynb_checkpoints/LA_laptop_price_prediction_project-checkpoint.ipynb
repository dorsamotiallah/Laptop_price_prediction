# %%
import pandas as pd 
import numpy as np
import sklearn as sk

from matplotlib import pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split #For spliting data into 2 sets of train and test

from sklearn.feature_selection import mutual_info_classif #For calculating information gain

from sklearn.linear_model import LinearRegression

from sklearn.linear_model import SGDRegressor
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("processed.csv")

# %%
df.head()
# Out:
#    ProductID     Price  Weight  DisplaySize  DisplayPixelWidth  \
# 0    3585871  28100000    1.90         15.6               1920
# 1    2896649  17640000    2.20         15.6               1366
# 2    3635241  39990000    1.09         14.0               1920
# 3    3430580  55350000    1.90         15.6               1920
# 4    3659939  17100000    2.10         15.6               1920
#
#    DisplayPixelHeight CPUCompany CPUModel  CPUSpeed  CPUCacheSize  \
# 0                1080      Intel  Core i7       2.8           8.0
# 1                 768      Intel  Core i3       2.0           4.0
# 2                1080      Intel  Core i7       2.8           8.0
# 3                1080      Intel  Core i7       NaN           8.0
# 4                1080      Intel  Core i3       2.8           4.0
#
#    RAMCapacity RAMTechnology
# 0            8          DDR4
# 1            4          DDR4
# 2           16          DDR4
# 3           16          DDR4
# 4            4          DDR4

# %%
X_encoded = pd.get_dummies(df, columns=['CPUModel', 'CPUCompany','RAMTechnology'], drop_first=True)
X_encoded
# Out:
#      ProductID     Price  Weight  DisplaySize  DisplayPixelWidth  \
# 0      3585871  28100000    1.90         15.6               1920
# 1      2896649  17640000    2.20         15.6               1366
# 2      3635241  39990000    1.09         14.0               1920
# 3      3430580  55350000    1.90         15.6               1920
# 4      3659939  17100000    2.10         15.6               1920
# ..         ...       ...     ...          ...                ...
# 242    3373528  24710000    2.00         15.6               1366
# 243    3516152  27990000    1.70         15.6               1920
# 244    3579826  43000000    2.20         15.6               1920
# 245    3644096  33000000    1.80         15.6               1920
# 246    3629341  27720000    1.90         15.6               1920
#
#      DisplayPixelHeight  CPUSpeed  CPUCacheSize  RAMCapacity  \
# 0                  1080       2.8           8.0            8
# 1                   768       2.0           4.0            4
# 2                  1080       2.8           8.0           16
# 3                  1080       NaN           8.0           16
# 4                  1080       2.8           4.0            4
# ..                  ...       ...           ...          ...
# 242                 768       2.0           6.0            8
# 243                1080       2.8           6.0           16
# 244                1080       2.5          12.0           16
# 245                1080       NaN           6.0            8
# 246                1080       NaN           8.0            8
#
#      CPUModel_Bristol Ridge  ...  CPUModel_Core i3  CPUModel_Core i5  \
# 0                         0  ...                 0                 0
# 1                         0  ...                 1                 0
# 2                         0  ...                 0                 0
# 3                         0  ...                 0                 0
# 4                         0  ...                 1                 0
# ..                      ...  ...               ...               ...
# 242                       0  ...                 0                 1
# 243                       0  ...                 0                 1
# 244                       0  ...                 0                 0
# 245                       0  ...                 0                 1
# 246                       0  ...                 0                 0
#
#      CPUModel_Core i7  CPUModel_Pentium  CPUModel_Ryzen 3  CPUModel_Ryzen 5  \
# 0                   1                 0                 0                 0
# 1                   0                 0                 0                 0
# 2                   1                 0                 0                 0
# 3                   1                 0                 0                 0
# 4                   0                 0                 0                 0
# ..                ...               ...               ...               ...
# 242                 0                 0                 0                 0
# 243                 0                 0                 0                 0
# 244                 1                 0                 0                 0
# 245                 0                 0                 0                 0
# 246                 1                 0                 0                 0
#
#      CPUModel_Ryzen 7  CPUModel_Xeon  CPUCompany_Intel  RAMTechnology_DDR4
# 0                   0              0                 1                   1
# 1                   0              0                 1                   1
# 2                   0              0                 1                   1
# 3                   0              0                 1                   1
# 4                   0              0                 1                   1
# ..                ...            ...               ...                 ...
# 242                 0              0                 1                   1
# 243                 0              0                 1                   1
# 244                 0              0                 1                   1
# 245                 0              0                 1                   1
# 246                 0              0                 1                   1
#
# [247 rows x 22 columns]

# %%
X_encoded = X_encoded.dropna() 
X_encoded
# Out:
#      ProductID      Price  Weight  DisplaySize  DisplayPixelWidth  \
# 0      3585871   28100000    1.90         15.6               1920
# 1      2896649   17640000    2.20         15.6               1366
# 2      3635241   39990000    1.09         14.0               1920
# 4      3659939   17100000    2.10         15.6               1920
# 5      3560381   66940000    2.30         15.6               1920
# ..         ...        ...     ...          ...                ...
# 239    3545629  117000000    2.60         17.3               1920
# 241    3587135   16340000    2.10         15.6               1366
# 242    3373528   24710000    2.00         15.6               1366
# 243    3516152   27990000    1.70         15.6               1920
# 244    3579826   43000000    2.20         15.6               1920
#
#      DisplayPixelHeight  CPUSpeed  CPUCacheSize  RAMCapacity  \
# 0                  1080       2.8           8.0            8
# 1                   768       2.0           4.0            4
# 2                  1080       2.8           8.0           16
# 4                  1080       2.8           4.0            4
# 5                  1080       2.5          12.0           16
# ..                  ...       ...           ...          ...
# 239                1080       2.8          12.0           32
# 241                 768       2.2           4.0            4
# 242                 768       2.0           6.0            8
# 243                1080       2.8           6.0           16
# 244                1080       2.5          12.0           16
#
#      CPUModel_Bristol Ridge  ...  CPUModel_Core i3  CPUModel_Core i5  \
# 0                         0  ...                 0                 0
# 1                         0  ...                 1                 0
# 2                         0  ...                 0                 0
# 4                         0  ...                 1                 0
# 5                         0  ...                 0                 0
# ..                      ...  ...               ...               ...
# 239                       0  ...                 0                 0
# 241                       0  ...                 1                 0
# 242                       0  ...                 0                 1
# 243                       0  ...                 0                 1
# 244                       0  ...                 0                 0
#
#      CPUModel_Core i7  CPUModel_Pentium  CPUModel_Ryzen 3  CPUModel_Ryzen 5  \
# 0                   1                 0                 0                 0
# 1                   0                 0                 0                 0
# 2                   1                 0                 0                 0
# 4                   0                 0                 0                 0
# 5                   1                 0                 0                 0
# ..                ...               ...               ...               ...
# 239                 1                 0                 0                 0
# 241                 0                 0                 0                 0
# 242                 0                 0                 0                 0
# 243                 0                 0                 0                 0
# 244                 1                 0                 0                 0
#
#      CPUModel_Ryzen 7  CPUModel_Xeon  CPUCompany_Intel  RAMTechnology_DDR4
# 0                   0              0                 1                   1
# 1                   0              0                 1                   1
# 2                   0              0                 1                   1
# 4                   0              0                 1                   1
# 5                   0              0                 1                   1
# ..                ...            ...               ...                 ...
# 239                 0              0                 1                   1
# 241                 0              0                 1                   1
# 242                 0              0                 1                   1
# 243                 0              0                 1                   1
# 244                 0              0                 1                   1
#
# [219 rows x 22 columns]

# %%
y = X_encoded['Price']
X_mic = X_encoded.drop(columns=['Price'])
mic = mutual_info_classif(X_mic, y, discrete_features=True)
# X_mic 
# y
fig = plt.figure(figsize=(20,8))
plt.plot(X_mic.columns, mic, color='#C0392B', linestyle='dashed', marker='o', markerfacecolor='#EDBB99', markersize=10)
plt.title('Gain vs Features values')
plt.xlabel('Features')
plt.ylabel('Gain')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/cluster/_supervised.py:58: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/cluster/_supervised.py:58: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/cluster/_supervised.py:58: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# Text(0, 0.5, 'Gain')

# %%
X_mic = X_mic.drop(columns=['ProductID'])
mic = mutual_info_classif(X_mic, y, discrete_features=True)
# X_mic 
# y
fig = plt.figure(figsize=(20,8))
plt.plot(X_mic.columns, mic, color='#C0392B', linestyle='dashed', marker='o', markerfacecolor='#EDBB99', markersize=10)
plt.title('Gain vs Features values')
plt.xlabel('Features')
plt.ylabel('Gain')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/cluster/_supervised.py:58: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/cluster/_supervised.py:58: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/cluster/_supervised.py:58: UserWarning: Clustering metrics expects discrete values but received continuous values for label, and multiclass values for target
#   warnings.warn(msg, UserWarning)
# Text(0, 0.5, 'Gain')

# %%
#seprating dataset for train and test
X_train , X_test ,y_train , y_test = train_test_split(X_mic,y, test_size=0.2, train_size=0.8, shuffle=True)

# %%
# preproccessing and normalization then fitting a model
# X_trainp = X_train.reshape(-1,1)
y_trainp = y_train.ravel()
reg = make_pipeline(StandardScaler(),SGDRegressor(max_iter=1000, tol=1e-3))
reg.fit(X_train, y_trainp)
Pipeline(steps=[('standardscaler', StandardScaler()),
                ('sgdregressor', SGDRegressor())])
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('sgdregressor', SGDRegressor())])

# %%
coeffs = pd.DataFrame(reg.named_steps['sgdregressor'].coef_,X_mic.columns,columns=['Coefficient'])
coeffs
# Out:
#                          Coefficient
# Weight                  4.902008e+05
# DisplaySize            -2.909234e+06
# DisplayPixelWidth      -1.981696e+06
# DisplayPixelHeight      7.096639e+06
# CPUSpeed               -1.034091e+05
# CPUCacheSize            1.342326e+07
# RAMCapacity             6.923881e+06
# CPUModel_Bristol Ridge  1.098580e+06
# CPUModel_Carrizo        0.000000e+00
# CPUModel_Celeron       -4.330016e+05
# CPUModel_Core i3        1.310243e+06
# CPUModel_Core i5       -2.623607e+05
# CPUModel_Core i7       -2.768673e+06
# CPUModel_Pentium        8.070090e+05
# CPUModel_Ryzen 3       -1.107425e+05
# CPUModel_Ryzen 5       -1.539852e+05
# CPUModel_Ryzen 7        2.004648e+05
# CPUModel_Xeon           7.033626e+06
# CPUCompany_Intel       -6.979342e+05
# RAMTechnology_DDR4     -2.151372e+06

# %%
# testing model
# X_testp = X_test.reshape(-1,1)
yhat = reg.predict(X_test)

# %%
# checking accuracy of model
reg.score(X_test,y_test)
# reg.r2_score(y_test,y_pred)
# Out:
# 0.9162557561197499

# %%
# ploting dataset and linear model together
plt.figure(figsize=(20,10))
plt.scatter(y_test,yhat, c = 'lightskyblue')
plt.ylabel("prediction")
plt.xlabel("y_test")
plt.plot(y_test,y_test, color='r')
